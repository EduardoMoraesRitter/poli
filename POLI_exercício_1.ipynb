# %% [markdown]
# <a href="https://colab.research.google.com/github/EduardoMoraesRitter/poli/blob/main/POLI_exerc%C3%ADcio_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel("soja_milho.xlsx")

df.head()
#observacao = qualitativo
#data  = qualitativo
#mes = Quantitativo discreto ?
#ano safra = qualitativo ?

#preço milho = Quantitativo contínuo
#preço soja = Quantitativo contínuo
# Out:
#    Observação        Data  Mês  Ano - Safra  Preços - Milho  Preços - Soja
# 0           1  02/01/2014    1         2014           26.64          72.18
# 1           2  03/01/2014    1         2014           27.00          71.42
# 2           3  06/01/2014    1         2014           27.29          71.38
# 3           4  07/01/2014    1         2014           27.49          70.31
# 4           5  08/01/2014    1         2014           27.16          70.14

# %%
df.describe()
# Out:
#        Observação         Mês  Ano - Safra  Preços - Milho  Preços - Soja
# count  498.000000  498.000000   498.000000      498.000000     498.000000
# mean   249.500000    6.528112  2014.497992       27.955080      66.498273
# std    143.904482    3.433211     0.500499        3.563466       5.804226
# min      1.000000    1.000000  2014.000000       21.760000      56.740000
# 25%    125.250000    4.000000  2014.000000       25.510000      62.302500
# 50%    249.500000    7.000000  2014.000000       27.535000      65.165000
# 75%    373.750000    9.000000  2015.000000       30.320000      69.187500
# max    498.000000   12.000000  2015.000000       36.830000      79.860000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.boxplot(x=df['Preços - Milho'])

# %%
sns.boxplot(x=df['Preços - Soja'])

# %%
ax = sns.boxplot(data=df['Preços - Soja'])
ax = sns.swarmplot(data=df['Preços - Soja'], color=".25")

# %%
ax = sns.boxplot(data=df['Preços - Milho'])
ax = sns.swarmplot(data=df['Preços - Milho'], color=".25")

# %%
df['Preços - Soja'].hist()

# %%
df['Preços - Milho'].hist()

# %%
df.corr()
# Out:
#                 Observação       Mês  ...  Preços - Milho  Preços - Soja
# Observação        1.000000  0.496192  ...        0.295683       0.432048
# Mês               0.496192  1.000000  ...        0.054193       0.316132
# Ano - Safra       0.866020 -0.002309  ...        0.305910       0.315516
# Preços - Milho    0.295683  0.054193  ...        1.000000       0.749095
# Preços - Soja     0.432048  0.316132  ...        0.749095       1.000000
#
# [5 rows x 5 columns]

# %%
corrMatrix = df.corr()
sn.heatmap(corrMatrix, annot=True)
plt.show()

# %%
sns.pairplot(df)
